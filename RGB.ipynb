# %%
import imageio
import matplotlib.pyplot as plt

# %%
#https://www.codementor.io/@innat_2k14/image-data-analysis-using-numpy-opencv-part-1-kfadbafx6

# %%
pic = imageio.imread('BChristy.jpg')
plt.figure(figsize = (15,15))

plt.imshow(pic)
# Out:
# C:\Users\annav\AppData\Local\Temp\ipykernel_36512\797911817.py:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning dissapear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   pic = imageio.imread('BChristy.jpg')

# %%
print('Type of the image : ' , type(pic))
print()
print('Shape of the image : {}'.format(pic.shape))
print('Image Hight {}'.format(pic.shape[0]))
print('Image Width {}'.format(pic.shape[1]))
print('Dimension of Image {}'.format(pic.ndim))
# Out:
# Type of the image :  <class 'imageio.core.util.Array'>
#
# Shape of the image : (512, 379, 3)
# Image Hight 512
# Image Width 379
# Dimension of Image 3

# %%
print('Image size {}'.format(pic.size))
print('Maximum RGB value in this image {}'.format(pic.max()))
print('Minimum RGB value in this image {}'.format(pic.min()))
# Out:
# Image size 582144
# Maximum RGB value in this image 255
# Minimum RGB value in this image 0

# %%
## let's look at a single pixel in R, G, B
pic[ 100, 50 ]
# Out:
# Array([108,  97, 202], dtype=uint8)

# %%
## let's look at the red channel 
plt.title('R channel')
plt.ylabel('Height {}'.format(pic.shape[0]))
plt.xlabel('Width {}'.format(pic.shape[1]))

plt.imshow(pic[ : , : , 0])
plt.colorbar()
plt.show()

## can I format these as the diff colors??

# %%
## let's look at the blue channel 
plt.title('B channel')
plt.ylabel('Height {}'.format(pic.shape[0]))
plt.xlabel('Width {}'.format(pic.shape[1]))

plt.imshow(pic[ : , : , 2])
plt.colorbar()
plt.show()

# %%
#### Splitting the image
import numpy as np
pic = imageio.imread('BChristy.jpg')

fig, ax = plt.subplots(nrows = 1, ncols=3, figsize=(15,5))

for c, ax in zip(range(3), ax):
    
    # create zero matrix
    split_img = np.zeros(pic.shape, dtype="uint8") # 'dtype' by default: 'numpy.float64'
    
    # assing each channel 
    split_img[ :, :, c] = pic[ :, :, c]
    
    # display each channel
    ax.imshow(split_img)
# Out:
# C:\Users\annav\AppData\Local\Temp\ipykernel_36512\2679874724.py:3: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning dissapear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   pic = imageio.imread('BChristy.jpg')

# %%
### how to evaluate the intensity of blue? 
# tuple to select colors of each channel line
colors = ("red", "green", "blue")

# create the histogram plot, with three lines, one for
# each color
plt.figure()
plt.xlim([0, 256])
for channel_id, color in enumerate(colors):
    histogram, bin_edges = np.histogram(
        pic[:, :, channel_id], bins=256, range=(0, 256)
    )
    plt.plot(bin_edges[0:-1], histogram, color=color)

plt.title("Color Histogram")
plt.xlabel("Color value")
plt.ylabel("Pixel count")
# Out:
# Text(0, 0.5, 'Pixel count')

# %%
### okay so a good estimate of how blue an image is could be:
